# %% [markdown]
# 🤗 라이브러리 설치후 런타임 재시작 🤗

# %%
# !pip install transformers sentencepiece datasets accelerate -qqq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 46.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.4/261.4 kB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.9 MB/s eta 0:00:00

# %% [markdown]
# <img src="https://i.imgur.com/boeFH8S.png" width="700px" />

# %% [markdown]
# # 1.모델 (Model)

# %% [markdown]
# ## 1.1. AutoModel 클래스 (Class)

# %% [markdown]
# ### 1) from_pretrained()

# %% [markdown]
# ### 2) from_config()

# %% [markdown]
# ### 3) 모델 사이즈 변경 방법

# %% [markdown]
# ## 1.2. 특정 모델 클래스 (Class)

# %% [markdown]
# ### BERT 모델 클래스

# %% [markdown]
# ### GPT-2 모델 클래스

# %% [markdown]
# # 2.토크나이저 (Tokenizer)

# %% [markdown]
# ## 2.1. 토크나이저 기본용법

# %% [markdown]
# ## 2.2. 다양한 모델의 토크나이저

# %% [markdown]
# # 3.데이터세트 (Datasets)

# %% [markdown]
# ## 3.1. 데이터 로딩 : load_dataset

# %% [markdown]
# ### 3.1.1. 파일로 부터 불러오기

# %%
from datasets import load_dataset

# csv 불러오기

# %%
# json 불러오기
from datasets import load_dataset

# csv 불러오기

# %% [markdown]
# ### 3.1.2. 웹에서 직접 불러오기

# %%
from datasets import load_dataset

url = 'https://raw.githubusercontent.com/exlmkr/exlm-data-hub/main/california_housing_train.csv'

# %%
from datasets import load_dataset

url = 'https://raw.githubusercontent.com/exlmkr/exlm-data-hub/main/anscombe.json'

# %% [markdown]
# ### 3.1.3. 🤗 허브에서 불러오기

# %%
from datasets import load_dataset

# dataset = load_dataset('wikitext', 'wikitext-103-v1')

# %% [markdown]
# ## 3.2. 데이터 전처리 : Dataset.map()

# %% [markdown]
# ### 3.2.1. Dataset.map() 기본 용법

# %%
from datasets import load_dataset

dataset = load_dataset('imdb', split="train[:1000]")

# %%
train_dataset[0]['length']

# %%
len(train_dataset[0]['text'])

# %% [markdown]
# ### 3.2.2. 토크나이저 적용

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# %% [markdown]
# ### 3.2.3. 병렬 처리

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

def tokenize(examples):
    return tokenizer(examples["text"], padding=True, max_length=50)

tokenized_dataset = dataset.map(tokenize, batched=True)

# %% [markdown]
# # 4. 훈련 API (Trainer)

# %% [markdown]
# ## 4.2. Trainer API 사용 예제

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments
from datasets import load_dataset


# 1. 작업 정의: 문장 생성

# 2. 학습 데이터 로딩
train_dataset = load_dataset('wikitext', 'wikitext-103-raw-v1', split='train[:1000]')


# 3. 토크나이저와 모델 로딩

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token

model = GPT2LMHeadModel.from_pretrained('gpt2')


# 4. 학습 데이터 전처리
def tokenize_function(examples):
	output = tokenizer(examples["text"], padding="max_length", truncation=True, max_length=512)
	return output

# map 함수를 이용한 토크나이징
tokenized_datasets = train_dataset.map(tokenize_function, batched=True, remove_columns=["text"])

# 데이터 콜레이터 설정
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
# 5. 모델 학습
# 학습을 위한 설정
training_args = TrainingArguments(
	output_dir="./gpt2_finetuned",
	overwrite_output_dir=True,
	num_train_epochs=3,
	per_device_train_batch_size=2,
	save_steps=1000,
	save_total_limit=2,
)

# Trainer 객체를 생성
trainer = Trainer(
	model=model,
	args=training_args,
	data_collator=data_collator,
	train_dataset=tokenized_datasets,
)

# 학습 시작
trainer.train()

# %% [markdown]
# ## 4.3. DataCollator

# %% [markdown]
# ### DataCollatorForLanguageModeling

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=False
)

# %% [markdown]
# ### DataCollatorForTokenClassification

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(
    tokenizer=tokenizer
)

# %% [markdown]
# ### DataCollatorWithPadding

# %%
from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(
    tokenizer=tokenizer
)

# %% [markdown]
# ### DataCollatorForSeq2Seq

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer
)

# %% [markdown]
# # 5. 파이프라인 (pipeline)

# %% [markdown]
# ## 5.1. 감성 분석 (sentiment-analysis)

# %% [markdown]
# ## 5.1. 감성 분석

# %%
from transformers import pipeline

# %% [markdown]
# ## 5.2. 문장 번역

# %%
from transformers import pipeline

# %% [markdown]
# ## 5.3. 문장 생성

# %%
from transformers import pipeline

# %% [markdown]
# ## 5.4. 다양한 용법

# %% [markdown]
# ### 5.4.1. pipeline 기본 용법

# %%
from transformers import pipeline

# %% [markdown]
# ### 5.4.2. pipeline 특정 모델 지정

# %%
from transformers import pipeline

nlp = pipeline("text-generation")

result = nlp("In a world where AI", max_length=50)

# %% [markdown]
# ### 5.4.3. pipeline 세부 옵션

# %%
from transformers import pipeline

nlp = pipeline("text-generation", model="gpt2")
result = nlp("In a world where AI", max_length=50)

print(result)

# %% [markdown]
# <img src="https://i.imgur.com/boeFH8S.png" width="700px" />

# %% [markdown]
# 끝.
